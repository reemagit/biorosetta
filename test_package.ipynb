# %%
import biorosetta as br
import importlib as imp
imp.reload(br)
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /var/folders/m7/zm8cz6t57dx2yksvbbs0zlh40000gp/T/ipykernel_79360/946225836.py:5: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
gene_list=[1643, 10987, 23369, 1044, 10015, 2185, 10107, 3320, 55014, 9342]
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()]) # Multiple sources
idmap.convert(gene_list,'entr','symb',df=True, multi_hits='all')
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# querying 1-10...done.
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:355: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:355: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:355: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
#    input    output   ensembl      hgnc    mygene  mismatch  ensembl_hits  \
# 0   1643      DDB2      DDB2      DDB2      DDB2     False             1
# 1  10987     COPS5     COPS5     COPS5     COPS5     False             1
# 2  23369      PUM2      PUM2      PUM2      PUM2     False             1
# 3   1044      CDX1      CDX1      CDX1      CDX1     False             1
# 4  10015   PDCD6IP   PDCD6IP   PDCD6IP   PDCD6IP     False             1
# 5   2185     PTK2B     PTK2B     PTK2B     PTK2B     False             1
# 6  10107    TRIM10    TRIM10    TRIM10    TRIM10     False             1
# 7   3320  HSP90AA1  HSP90AA1  HSP90AA1  HSP90AA1     False             1
# 8  55014     STX17     STX17     STX17     STX17     False             1
# 9   9342    SNAP29    SNAP29    SNAP29    SNAP29     False             1
#
#    hgnc_hits  mygene_hits
# 0          1            1
# 1          1            1
# 2          1            1
# 3          1            1
# 4          1            1
# 5          1            1
# 6          1            1
# 7          1            1
# 8          1            1
# 9          1            1

# %%
gene_list = pd.read_table('/Users/reema/Postdoc/Temp/ENSP_nodes.csv',sep=',').node_name.tolist()

# %%
pd.options.display.max_rows = 100
pd.options.display.min_rows = 100

# %%
idmap.convert(gene_list,'ensp','entr',df=False, multi_hits='first')
# Out:
# One or more sources do not support the requested input/output ID type mapping: hgnc,mygene
# Mapping will be executed using the following source(s): ensembl
# ['51107',
#  '9862',
#  '8772',
#  '9454',
#  '8704',
#  '285313',
#  '55061',
#  '30012',
#  '23002',
#  '2635',
#  '6418',
#  '85458',
#  '8437',
#  '79041',
#  '153527',
#  '6443',
#  '5540',
#  '8318',
#  '8987',
#  'N/A',
#  '51398',
#  '389812',
#  '284565',
#  '10162',
#  '2158',
#  '221927',
#  '10970',
#  '4478',
#  '80778',
#  '5326',
#  'N/A',
#  '55802',
#  '127495',
#  '84654',
#  '338872',
#  '1155',
#  '148523',
#  '8290',
#  '4115',
#  '116444',
#  '1903',
#  '2683',
#  '9187',
#  '1272',
#  'N/A',
#  '26952',
#  '80176',
#  '57126',
#  '2897',
#  '284339',
#  '51426',
#  '23432',
#  '285237',
#  '64816',
#  '339302',
#  '1992',
#  '343637',
#  '51286',
#  '3818',
#  '25806',
#  '23495',
#  '30819',
#  '1388',
#  '55039',
#  '81533',
#  '83941',
#  '122011',
#  'N/A',
#  '54482',
#  '794',
#  '6773',
#  '3445',
#  '51750',
#  '541565',
#  '5711',
#  '10381',
#  '84868',
#  '9607',
#  '54960',
#  '4935',
#  '727764',
#  '55351',
#  '25900',
#  '7851',
#  '23576',
#  '144717',
#  '84888',
#  '642475',
#  '6943',
#  '6263',
#  '387129',
#  '285362',
#  '10616',
#  '6919',
#  '284656',
#  '9326',
#  '51157',
#  'N/A',
#  '64582',
#  '1821',
#  '133746',
#  '100302736',
#  '347051',
#  '143689',
#  '25788',
#  '7225',
#  '63893',
#  '84163',
#  'N/A',
#  '84955',
#  '204962',
#  'N/A',
#  '145282',
#  '151648',
#  '10220',
#  '55786',
#  '57088',
#  '79727',
#  '221264',
#  '3512',
#  '55017',
#  '3071',
#  '84197',
#  '5476',
#  '171177',
#  '3002',
#  '178',
#  '23632',
#  '728386',
#  '390790',
#  '7448',
#  '3620',
#  '3181',
#  '5442',
#  '9104',
#  '84293',
#  '63027',
#  '36',
#  '23500',
#  '51495',
#  '283208',
#  '4648',
#  '4438',
#  'N/A',
#  '9925',
#  '161394',
#  '2169',
#  '158067',
#  '100288332',
#  '9746',
#  '284439',
#  '10859',
#  '284695',
#  '56269',
#  '4013',
#  '7001',
#  '4099',
#  '440051',
#  '25984',
#  '8900',
#  '2246',
#  '56252',
#  '254295',
#  '5420',
#  '655',
#  '4643',
#  '55573',
#  '10747',
#  '1536',
#  '31',
#  '57826',
#  '65018',
#  '134391',
#  '8861',
#  '116228',
#  '22936',
#  '117285',
#  '6868',
#  '3899',
#  '6337',
#  '2204',
#  '56890',
#  '1672',
#  '8689',
#  '54487',
#  '5334',
#  '8991',
#  '256051',
#  '1842',
#  '8496',
#  '6992',
#  '8976',
#  '200879',
#  '388553',
#  '4325',
#  '2251',
#  '908',
#  '64109',
#  '25920',
#  '6695',
#  '2744',
#  '57447',
#  '56123',
#  '284111',
#  '100500938',
#  '23415',
#  '5676',
#  '128637',
#  '729250',
#  '79074',
#  '55137',
#  '5721',
#  '55835',
#  '85437',
#  '91851',
#  '162394',
#  '29118',
#  '222236',
#  '8019',
#  '7918',
#  '921',
#  '23033',
#  '401934',
#  '8492',
#  '56475',
#  '57091',
#  '9398',
#  '56931',
#  '53944',
#  '10169',
#  '80335',
#  '658',
#  '6795',
#  '57132',
#  '146183',
#  '9363',
#  '78994',
#  '1081',
#  '3351',
#  '11025',
#  '4513',
#  '340527',
#  '28956',
#  '440138',
#  '26228',
#  '7780',
#  '1215',
#  '2626',
#  '6917',
#  '10575',
#  '55954',
#  '84553',
#  '63897',
#  '118881',
#  '7813',
#  '221545',
#  '56751',
#  '6566',
#  '340204',
#  '27330',
#  '24139',
#  '80736',
#  '131540',
#  '56132',
#  '2107',
#  '282809',
#  '10051',
#  '54780',
#  '63932',
#  '2249',
#  '10081',
#  '25844',
#  '5989',
#  '672',
#  '128',
#  '92211',
#  '64393',
#  '7374',
#  '8351',
#  '1677',
#  '9721',
#  '4589',
#  '151126',
#  '26256',
#  '90204',
#  '50865',
#  '348980',
#  '389434',
#  '1017',
#  '374977',
#  '6386',
#  '5706',
#  '215',
#  '23383',
#  '1068',
#  '129293',
#  '3834',
#  '2932',
#  '203074',
#  'N/A',
#  '57699',
#  '29082',
#  '3993',
#  '159013',
#  '124446',
#  'N/A',
#  '126731',
#  '55552',
#  '116071',
#  'N/A',
#  '60561',
#  '5906',
#  '55486',
#  '9923',
#  '7732',
#  '84313',
#  'N/A',
#  '64770',
#  '22861',
#  'N/A',
#  '254359',
#  '79831',
#  '9049',
#  'N/A',
#  '3364',
#  '84310',
#  '10817',
#  '157848',
#  '5927',
#  '8605',
#  '10878',
#  '3804',
#  '5947',
#  '56171',
#  '8674',
#  '79705',
#  '9464',
#  '4286',
#  '643246',
#  '56899',
#  '5305',
#  '6870',
#  '79696',
#  '5545',
#  '6545',
#  '54970',
#  '2063',
#  '51738',
#  '89765',
#  '344191',
#  'N/A',
#  '2330',
#  '10240',
#  'N/A',
#  '57037',
#  '7746',
#  '57862',
#  '80325',
#  '6691',
#  '55191',
#  '283989',
#  '128954',
#  '26586',
#  '654231',
#  '56902',
#  '1298',
#  '8505',
#  '8896',
#  '94241',
#  '57541',
#  '845',
#  '9481',
#  '64420',
#  '57409',
#  '8659',
#  '56851',
#  '134353',
#  '9202',
#  '387357',
#  '130589',
#  'N/A',
#  '51501',
#  '659',
#  '30827',
#  '442213',
#  '5297',
#  '60626',
#  '130574',
#  '117155',
#  '7128',
#  '10848',
#  '83879',
#  '23293',
#  '1454',
#  '6767',
#  '3431',
#  '150209',
#  '255403',
#  '255324',
#  '3357',
#  '89858',
#  '26291',
#  '51203',
#  '116443',
#  '253725',
#  '7584',
#  '340602',
#  '344758',
#  '374291',
#  '54865',
#  '140838',
#  'N/A',
#  '90075',
#  '252983',
#  '6511',
#  '222962',
#  '8641',
#  '1203',
#  '10193',
#  '81502',
#  '8557',
#  '257106',
#  '10890',
#  '57600',
#  '169270',
#  '4938',
#  '343071',
#  '120935',
#  '10087',
#  '10551',
#  '9986',
#  '24142',
#  '57180',
#  '29920',
#  '23654',
#  '135295',
#  '4048',
#  '116840',
#  '27087',
#  '81844',
#  '91749',
#  '58496',
#  '6399',
#  '155061',
#  '2272',
#  '85480',
#  '1875',
#  '9262',
#  '201191',
#  '7004',
#  '58490',
#  '132243',
#  '57494',
#  '55972',
#  '79839',
#  '124454',
#  '7568',
#  'N/A',
#  '7576',
#  '7365',
#  '2793',
#  '896',
#  '26258',
#  '25864',
#  '57099',
#  '9577',
#  '2864',
#  '284723',
#  '10488',
#  '401409',
#  '7917',
#  '387',
#  '6446',
#  '3562',
#  '4050',
#  '55529',
#  '1643',
#  '2595',
#  '611',
#  '27241',
#  '6874',
#  '11124',
#  '7039',
#  '1240',
#  '54856',
#  '23743',
#  '90',
#  '57504',
#  '55647',
#  '1735',
#  'N/A',
#  '23414',
#  '128240',
#  '100132396',
#  '55650',
#  '219899',
#  '51602',
#  '6518',
#  '6259',
#  '131616',
#  '23682',
#  '6557',
#  '57624',
#  '9352',
#  'N/A',
#  '80219',
#  'N/A',
#  '79018',
#  '7005',
#  '56925',
#  '5544',
#  'N/A',
#  '166',
#  '2911',
#  '79598',
#  '2309',
#  '4193',
#  '84639',
#  '967',
#  '644974',
#  '5534',
#  '113402',
#  '203102',
#  '2332',
#  '26151',
#  '55178',
#  '10781',
#  '57325',
#  '4172',
#  '23504',
#  '54855',
#  '10849',
#  '79370',
#  '8325',
#  '9529',
#  'N/A',
#  '85285',
#  '54586',
#  '602',
#  '84305',
#  '51686',
#  '83942',
#  '9451',
#  '23133',
#  '83449',
#  '3958',
#  '22929',
#  '51244',
#  '7364',
#  '2015',
#  '80149',
#  '8029',
#  '259282',
#  '374882',
#  'N/A',
#  '420',
#  '387914',
#  '10914',
#  '501',
#  '10628',
#  '440533',
#  '27253',
#  '91373',
#  '3764',
#  '408050',
#  '4259',
#  '58530',
#  '114818',
#  '55278',
#  '414328',
#  'N/A',
#  '134',
#  '201305',
#  '10858',
#  '30846',
#  '284958',
#  '6119',
#  '3270',
#  '79709',
#  '27297',
#  '84818',
#  '9475',
#  '1132',
#  '9698',
#  '26137',
#  '10196',
#  '6489',
#  '54937',
#  '9319',
#  '926',
#  '51668',
#  '1236',
#  '78992',
#  '23347',
#  '4357',
#  '10641',
#  '262',
#  '10352',
#  '127540',
#  '120425',
#  '2120',
#  '136259',
#  '345079',
#  '9093',
#  '51343',
#  '63947',
#  '5630',
#  '4319',
#  '7957',
#  'N/A',
#  '55184',
#  '11018',
#  '7136',
#  '9701',
#  '51622',
#  '5862',
#  '6833',
#  '23400',
#  '1730',
#  '6271',
#  '57381',
#  '653567',
#  '901',
#  '317762',
#  '80856',
#  '8454',
#  '109',
#  '204851',
#  '1312',
#  '55286',
#  '2662',
#  '8342',
#  '495',
#  '22901',
#  '7629',
#  '84246',
#  '6001',
#  '23464',
#  '149095',
#  '55859',
#  '388333',
#  '51704',
#  '3078',
#  '163255',
#  '83795',
#  '7181',
#  '6041',
#  '102723502',
#  '11164',
#  '8202',
#  '192668',
#  '51554',
#  '5164',
#  '91687',
#  '1364',
#  '57153',
#  '7143',
#  '4842',
#  '347475',
#  '8574',
#  '1259',
#  '79877',
#  '54543',
#  '64795',
#  '126074',
#  '84171',
#  '101059953',
#  '2906',
#  '7135',
#  '114883',
#  '142',
#  '154791',
#  '252839',
#  '10495',
#  '388323',
#  '5885',
#  '55818',
#  '10226',
#  '404672',
#  '9709',
#  '23417',
#  '200350',
#  '10965',
#  '87',
#  '6554',
#  '94121',
#  '25769',
#  '7325',
#  '57828',
#  '9092',
#  '30',
#  '79739',
#  '860',
#  '284119',
#  '55916',
#  '114932',
#  '340359',
#  '93380',
#  '9580',
#  '390243',
#  '79671',
#  '7993',
#  '284325',
#  '526',
#  '1667',
#  '8329',
#  '81551',
#  '220382',
#  '79170',
#  '7369',
#  '58517',
#  '132954',
#  '389941',
#  '51248',
#  '116064',
#  '51291',
#  '79090',
#  '29767',
#  '79713',
#  '5373',
#  '57567',
#  '7343',
#  '84879',
#  '50640',
#  '55892',
#  '389813',
#  '146325',
#  '2859',
#  '80343',
#  '79958',
#  '5467',
#  '138311',
#  '91661',
#  '1548',
#  '79837',
#  '57478',
#  '1412',
#  '51073',
#  '118471',
#  '5979',
#  '7272',
#  '54665',
#  '116983',
#  '58986',
#  '26155',
#  '64132',
#  '5222',
#  '4063',
#  '25924',
#  '339403',
#  '51626',
#  '493911',
#  '25759',
#  '4233',
#  '113540',
#  '757',
#  '84747',
#  '5996',
#  '9812',
#  '8570',
#  '9536',
#  '5433',
#  '121268',
#  '403277',
#  '2312',
#  '148327',
#  '6277',
#  '425054',
#  '27238',
#  '79752',
#  '399474',
#  '283726',
#  '51237',
#  '56937',
#  '57134',
#  '146754',
#  '23474',
#  '440145',
#  'N/A',
#  '5525',
#  '10206',
#  '5998',
#  '10527',
#  '51438',
#  '375323',
#  '4329',
#  '90273',
#  '54443',
#  '136541',
#  '84283',
#  '89882',
#  'N/A',
#  '5332',
#  '51642',
#  '151649',
#  '55745',
#  '5034',
#  'N/A',
#  '5455',
#  '643847',
#  '51056',
#  '94025',
#  '11187',
#  '9227',
#  '80740',
#  '54760',
#  '25963',
#  '6865',
#  '136227',
#  '51307',
#  '5609',
#  '1833',
#  '7453',
#  '3558',
#  'N/A',
#  '22978',
#  '23272',
#  '6725',
#  '5122',
#  '5375',
#  '57709',
#  '4176',
#  '54826',
#  '140465',
#  '55832',
#  '7518',
#  '55337',
#  '391002',
#  '55740',
#  '55766',
#  '219654',
#  '26998',
#  'N/A',
#  '7189',
#  '10735',
#  '23163',
#  '64106',
#  '55756',
#  '7249',
#  '197358',
#  '387715',
#  '1783',
#  '84179',
#  '100131608',
#  '5816',
#  '2689',
#  '29796',
#  '190',
#  '5000',
#  '100287932',
#  '9817',
#  '338323',
#  '161514',
#  '3643',
#  '4613',
#  '766',
#  '55167',
#  '9079',
#  '140870',
#  '10181',
#  '85366',
#  '55124',
#  '917',
#  'N/A',
#  '286827',
#  '51058',
#  '161247',
#  'N/A',
#  '50508',
#  '114804',
#  '122970',
#  '51119',
#  '10773',
#  '257397',
#  '51103',
#  '1386',
#  '4016',
#  '8649',
#  '29989',
#  '114821',
#  '26509',
#  '1346',
#  '37',
#  '8313',
#  '144448',
#  '4179',
#  '347365',
#  '6656',
#  '54544',
#  '11214',
#  '343578',
#  '201633',
#  '117143',
#  '54802',
#  'N/A',
#  'N/A',
#  '284697',
#  '84071',
#  '26094',
#  '10479',
#  '9315',
#  '204474',
#  '5692',
#  '23281',
#  '7494',
#  '55435',
#  '345',
#  '4904',
#  '51143',
#  '9697',
#  '11274',
#  '117286',
#  '79012',
#  '56034',
#  '825',
#  '7421',
#  '139081',
#  '84331',
#  '162073',
#  '5521',
#  '1410',
#  '63899',
#  '8908',
#  '6278',
#  '10825',
#  'N/A',
#  '7409',
#  '387496',
#  '28957',
#  '91734',
#  '23308',
#  '9061',
#  '5747',
#  '55165',
#  '6633',
#  '140686',
#  '3554',
#  '140691',
#  '7299',
#  '85409',
#  '8934',
#  '148304',
#  '79744',
#  '7695',
#  '2734',
#  '10335',
#  '51363',
#  '4534',
#  '646480',
#  '9958',
#  '4162',
#  '26751',
#  '83876',
#  '9361',
#  '51071',
#  '7251',
#  '23598',
#  '6752',
#  '257202',
#  '9796',
#  '8728',
#  '10544',
#  '350',
#  '169522',
#  '10933',
#  '23040',
#  '29103',
#  '1513',
#  '5208',
#  '4151',
#  '8553',
#  '4595',
#  '4145',
#  '55031',
#  '150221',
#  '79187',
#  'N/A',
#  '128346',
#  '1359',
#  '57522',
#  '57187',
#  '2253',
#  '6272',
#  '9826',
#  '145258',
#  '4882',
#  '84649',
#  '728239',
#  '256329',
#  'N/A',
#  '11060',
#  '5089',
#  '2623',
#  '51382',
#  '5791',
#  '23596',
#  '79668',
#  '84321',
#  '9043',
#  '89781',
#  ...]

# %%
# %debug
# Out:
# > /Users/reema/anaconda2/envs/biorosetta/lib/python3.10/site-packages/pandas/core/generic.py(1527)__nonzero__()
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ipdb> u
# > /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py(333)get_consensus()
#     331                 if multi_hits == 'consensus':
#     332                         def get_consensus(x):
# --> 333                                 if x != self._fill_value > 0:
#     334                                         return consensus_elem(x[x != self._fill_value].str.split('|').tolist())
#     335                                 else:
#
# ipdb> x
# ensembl    51107
# Name: 0, dtype: object
# ipdb> x != self._fill_value
# ensembl    True
# Name: 0, dtype: bool
# ipdb> (x != self._fill_value).sum()
# 1
# ipdb> exit
