# %%
import biorosetta as br
import importlib as imp
imp.reload(br)
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /var/folders/qt/cf8zfc4s2p16s8mnvmb9b_z00000gq/T/ipykernel_13212/946225836.py:5: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
gene_list=[1643, 10987, 23369, 1044, 10015, 2185, 10107, 3320, 55014, 9342]
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()]) # Multiple sources
idmap.convert(gene_list,'entr','symb',df=True, multi_hits='all')
# Out:
# INFO:biothings.client:querying 1-10...
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# INFO:biothings.client:done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/test_env/lib/python3.10/site-packages/pandas/core/generic.py:513, in NDFrame._get_axis_number(cls, axis)
#     512 try:
# --> 513     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514 except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 gene_list=[1643, 10987, 23369, 1044, 10015, 2185, 10107, 3320, 55014, 9342]
#       2 idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()]) # Multiple sources
# ----> 3 idmap.convert(gene_list,'entr','symb',df=True, multi_hits='all')
#
# File ~/Work/Libs/biorosetta/biorosetta/classes.py:360, in IDMapper.convert(self, id_list, id_in, id_out, multi_hits, df)
#     357 	out_df['output'] = out_df[src_ids].apply(get_consensus,axis=1)
#     358 	#id_list_out = out_df['consensus']
#     359 else:
# --> 360 	id_list_out = out_df[src_ids[0]].squeeze(axis=1)
#     361 	for i in range(1, len(src_ids)):
#     362 		idx = id_list_out == self._fill_value
#
# File ~/miniconda3/envs/test_env/lib/python3.10/site-packages/pandas/core/generic.py:962, in NDFrame.squeeze(self, axis)
#     858 @final
#     859 def squeeze(self, axis: Axis | None = None):
#     860     """
#     861     Squeeze 1 dimensional axis objects into scalars.
#     862
#    (...)
#     960     1
#     961     """
# --> 962     axes = range(self._AXIS_LEN) if axis is None else (self._get_axis_number(axis),)
#     963     return self.iloc[
#     964         tuple(
#     965             0 if i in axes and len(a) == 1 else slice(None)
#     966             for i, a in enumerate(self.axes)
#     967         )
#     968     ]
#
# File ~/miniconda3/envs/test_env/lib/python3.10/site-packages/pandas/core/generic.py:515, in NDFrame._get_axis_number(cls, axis)
#     513     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514 except KeyError:
# --> 515     raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named 1 for object type Series

# %%
# %debug
# Out:
# > /Users/enricomaiorino/miniconda3/envs/test_env/lib/python3.10/site-packages/pandas/core/generic.py(515)_get_axis_number()
#     513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
# --> 515             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     516
#     517     @final
#
# ipdb> u
# > /Users/enricomaiorino/miniconda3/envs/test_env/lib/python3.10/site-packages/pandas/core/generic.py(962)squeeze()
#     960         1
#     961         """
# --> 962         axes = range(self._AXIS_LEN) if axis is None else (self._get_axis_number(axis),)
#     963         return self.iloc[
#     964             tuple(
#
# ipdb> u
# > /Users/enricomaiorino/Work/Libs/biorosetta/biorosetta/classes.py(360)convert()
#     358                         #id_list_out = out_df['consensus']
#     359                 else:
# --> 360                         id_list_out = out_df[src_ids[0]].squeeze(axis=1)
#     361                         for i in range(1, len(src_ids)):
#     362                                 idx = id_list_out == self._fill_value
#
# ipdb> out_df[src_ids[0]]
# 0        DDB2
# 1       COPS5
# 2        PUM2
# 3        CDX1
# 4     PDCD6IP
# 5       PTK2B
# 6      TRIM10
# 7    HSP90AA1
# 8       STX17
# 9      SNAP29
# Name: ensembl, dtype: object
# ipdb> l
#     355                                         return self._fill_value
#     356
#     357                         out_df['output'] = out_df[src_ids].apply(get_consensus,axis=1)
#     358                         #id_list_out = out_df['consensus']
#     359                 else:
# --> 360                         id_list_out = out_df[src_ids[0]].squeeze(axis=1)
#     361                         for i in range(1, len(src_ids)):
#     362                                 idx = id_list_out == self._fill_value
#     363                                 if idx.sum().squeeze() == 0:
#     364                                         break
#     365                                 id_list_out[idx] = out_df.loc[idx, src_ids[i]].squeeze(axis=1)
#
# ipdb> out_df[src_ids[0]].squeeze(axis=1) == self._fill_value
# *** ValueError: No axis named 1 for object type Series
# ipdb> out_df[src_ids[0]] == self._fill_value
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: ensembl, dtype: bool
# ipdb> idx = out_df[src_ids[0]] == self._fill_value
# ipdb> idx.sum()
# 0
# ipdb> idx.sum().squeeze()
# 0
# ipdb> exit()

# %%
gene_list=[1643, 10987, 23369, 1044, 10015, 2185, 10107, 3320, 55014, 9342]
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()]) # Multiple sources
idmap.convert(gene_list,'entr','symb',df=True, multi_hits='all')
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-10...done.
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
#    input    output   ensembl      hgnc    mygene  mismatch  ensembl_hits  \
# 0   1643      DDB2      DDB2      DDB2      DDB2     False             1
# 1  10987     COPS5     COPS5     COPS5     COPS5     False             1
# 2  23369      PUM2      PUM2      PUM2      PUM2     False             1
# 3   1044      CDX1      CDX1      CDX1      CDX1     False             1
# 4  10015   PDCD6IP   PDCD6IP   PDCD6IP   PDCD6IP     False             1
# 5   2185     PTK2B     PTK2B     PTK2B     PTK2B     False             1
# 6  10107    TRIM10    TRIM10    TRIM10    TRIM10     False             1
# 7   3320  HSP90AA1  HSP90AA1  HSP90AA1  HSP90AA1     False             1
# 8  55014     STX17     STX17     STX17     STX17     False             1
# 9   9342    SNAP29    SNAP29    SNAP29    SNAP29     False             1
#
#    hgnc_hits  mygene_hits
# 0          1            1
# 1          1            1
# 2          1            1
# 3          1            1
# 4          1            1
# 5          1            1
# 6          1            1
# 7          1            1
# 8          1            1
# 9          1            1

# %%
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()], fill_value='passthrough') # Multiple sources
idmap.convert(gene_list,'entr','ensg',df=True)
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-10...done.
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
#    input           output          ensembl             hgnc           mygene  \
# 0   1643  ENSG00000134574  ENSG00000134574  ENSG00000134574  ENSG00000134574
# 1  10987  ENSG00000121022  ENSG00000121022  ENSG00000121022  ENSG00000121022
# 2  23369  ENSG00000055917  ENSG00000055917  ENSG00000055917  ENSG00000055917
# 3   1044  ENSG00000113722  ENSG00000113722  ENSG00000113722  ENSG00000113722
# 4  10015  ENSG00000170248  ENSG00000170248  ENSG00000170248  ENSG00000170248
# 5   2185  ENSG00000120899  ENSG00000120899  ENSG00000120899  ENSG00000120899
# 6  10107  ENSG00000237703  ENSG00000237703  ENSG00000204613            10107
# 7   3320  ENSG00000080824  ENSG00000080824  ENSG00000080824  ENSG00000080824
# 8  55014  ENSG00000136874  ENSG00000136874  ENSG00000136874  ENSG00000136874
# 9   9342  ENSG00000099940  ENSG00000099940  ENSG00000099940  ENSG00000099940
#
#    mismatch  ensembl_hits  hgnc_hits  mygene_hits
# 0     False             1          1            1
# 1     False             1          1            1
# 2     False             1          1            1
# 3     False             1          1            1
# 4     False             1          1            1
# 5     False             1          1            1
# 6      True             1          1            1
# 7     False             1          1            1
# 8     False             1          1            1
# 9     False             1          1            1

# %%
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()], fill_value='passthrough') # Multiple sources
idmap.convert(gene_list,'entr','symb',df=True)
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-10...done.
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
#    input    output   ensembl      hgnc    mygene  mismatch  ensembl_hits  \
# 0   1643      DDB2      DDB2      DDB2      DDB2     False             1
# 1  10987     COPS5     COPS5     COPS5     COPS5     False             1
# 2  23369      PUM2      PUM2      PUM2      PUM2     False             1
# 3   1044      CDX1      CDX1      CDX1      CDX1     False             1
# 4  10015   PDCD6IP   PDCD6IP   PDCD6IP   PDCD6IP     False             1
# 5   2185     PTK2B     PTK2B     PTK2B     PTK2B     False             1
# 6  10107    TRIM10    TRIM10    TRIM10    TRIM10     False             1
# 7   3320  HSP90AA1  HSP90AA1  HSP90AA1  HSP90AA1     False             1
# 8  55014     STX17     STX17     STX17     STX17     False             1
# 9   9342    SNAP29    SNAP29    SNAP29    SNAP29     False             1
#
#    hgnc_hits  mygene_hits
# 0          1            1
# 1          1            1
# 2          1            1
# 3          1            1
# 4          1            1
# 5          1            1
# 6          1            1
# 7          1            1
# 8          1            1
# 9          1            1

# %%
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()], fill_value='passthrough') # Multiple sources
print(idmap.convert(gene_list[:3],'entr','ensg',df=True).to_markdown())
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-3...done.
# |    |   input | output          | ensembl         | hgnc            | mygene          | mismatch   |   ensembl_hits |   hgnc_hits |   mygene_hits |
# |---:|--------:|:----------------|:----------------|:----------------|:----------------|:-----------|---------------:|------------:|--------------:|
# |  0 |    1643 | ENSG00000134574 | ENSG00000134574 | ENSG00000134574 | ENSG00000134574 | False      |              1 |           1 |             1 |
# |  1 |   10987 | ENSG00000121022 | ENSG00000121022 | ENSG00000121022 | ENSG00000121022 | False      |              1 |           1 |             1 |
# |  2 |   23369 | ENSG00000055917 | ENSG00000055917 | ENSG00000055917 | ENSG00000055917 | False      |              1 |           1 |             1 |
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))

# %%
idmap.convert(['ENSG00000159388','ENSG00000121022','ENSG00000134574'],'ensg','entr')
# Out:
# querying 1-3...done.
# ['7832', '10987', '1643']

# %%
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()]) # Multiple sources
idmap.convert(['ENSG00000271254'],'ensg','entr',df=True, multi_hits='consensus')
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-1...done.
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
#              input     output    ensembl hgnc     mygene  mismatch  \
# 0  ENSG00000271254  102724250  102724250  N/A  102724250     False
#
#    ensembl_hits  hgnc_hits  mygene_hits
# 0             1        0.0            1

# %%
[elem for elem in idmap._sources[0]._lookup['ensg']['entr'].index if elem not in idmap._sources[1]._lookup['ensg']['entr'].index]
# Out:
# ['ENSG00000271254',
#  'ENSG00000280663',
#  'ENSG00000262826',
#  'ENSG00000273947',
#  'ENSG00000273735',
#  'ENSG00000275717',
#  'ENSG00000276379',
#  'ENSG00000276433',
#  'ENSG00000275442',
#  'ENSG00000274692',
#  'ENSG00000277484',
#  'ENSG00000275062',
#  'ENSG00000277554',
#  'ENSG00000277272',
#  'ENSG00000277044',
#  'ENSG00000277339',
#  'ENSG00000274807',
#  'ENSG00000274714',
#  'ENSG00000276876',
#  'ENSG00000277334',
#  'ENSG00000276885',
#  'ENSG00000275786',
#  'ENSG00000277982',
#  'ENSG00000277267',
#  'ENSG00000273510',
#  'ENSG00000274324',
#  'ENSG00000276423',
#  'ENSG00000276534',
#  'ENSG00000276820',
#  'ENSG00000278731',
#  'ENSG00000278306',
#  'ENSG00000277620',
#  'ENSG00000281362',
#  'ENSG00000274948',
#  'ENSG00000276858',
#  'ENSG00000276328',
#  'ENSG00000274696',
#  'ENSG00000275407',
#  'ENSG00000278805',
#  'ENSG00000277345',
#  'ENSG00000275914',
#  'ENSG00000276424',
#  'ENSG00000277616',
#  'ENSG00000273526',
#  'ENSG00000278207',
#  'ENSG00000275433',
#  'ENSG00000277650',
#  'ENSG00000273738',
#  'ENSG00000277725',
#  'ENSG00000273661',
#  'ENSG00000274722',
#  'ENSG00000274842',
#  'ENSG00000274406',
#  'ENSG00000276501',
#  'ENSG00000275276',
#  'ENSG00000274782',
#  'ENSG00000276676',
#  'ENSG00000281935',
#  'ENSG00000274861',
#  'ENSG00000275008',
#  'ENSG00000275599',
#  'ENSG00000273775',
#  'ENSG00000274830',
#  'ENSG00000274283',
#  'ENSG00000277078',
#  'ENSG00000276004',
#  'ENSG00000275659',
#  'ENSG00000276084',
#  'ENSG00000276459',
#  'ENSG00000276329',
#  'ENSG00000278248',
#  'ENSG00000273518',
#  'ENSG00000275080',
#  'ENSG00000276985',
#  'ENSG00000275436',
#  'ENSG00000274480',
#  'ENSG00000275351',
#  'ENSG00000275035',
#  'ENSG00000277833',
#  'ENSG00000276357',
#  'ENSG00000276806',
#  'ENSG00000275289',
#  'ENSG00000274826',
#  'ENSG00000278369',
#  'ENSG00000261992',
#  'ENSG00000274920',
#  'ENSG00000273887',
#  'ENSG00000276450',
#  'ENSG00000275970',
#  'ENSG00000274707',
#  'ENSG00000274724',
#  'ENSG00000276247',
#  'ENSG00000263163',
#  'ENSG00000274243',
#  'ENSG00000276590',
#  'ENSG00000275269',
#  'ENSG00000274120',
#  'ENSG00000278414',
#  'ENSG00000275750',
#  'ENSG00000278327',
#  'ENSG00000275421',
#  'ENSG00000275136',
#  'ENSG00000278304',
#  'ENSG00000275172',
#  'ENSG00000277963',
#  'ENSG00000278780',
#  'ENSG00000273517',
#  'ENSG00000275521',
#  'ENSG00000275938',
#  'ENSG00000274556',
#  'ENSG00000278474',
#  'ENSG00000277317',
#  'ENSG00000274402',
#  'ENSG00000276930',
#  'ENSG00000278710',
#  'ENSG00000273528',
#  'ENSG00000273755',
#  'ENSG00000278091',
#  'ENSG00000275486',
#  'ENSG00000278442',
#  'ENSG00000277193',
#  'ENSG00000274639',
#  'ENSG00000276392',
#  'ENSG00000273578',
#  'ENSG00000278079',
#  'ENSG00000273794',
#  'ENSG00000278850',
#  'ENSG00000276498',
#  'ENSG00000275288',
#  'ENSG00000277630',
#  'ENSG00000275050',
#  'ENSG00000275262',
#  'ENSG00000276154',
#  'ENSG00000277596',
#  'ENSG00000278856',
#  'ENSG00000274563',
#  'ENSG00000275083',
#  'ENSG00000278793',
#  'ENSG00000277657',
#  'ENSG00000275513',
#  'ENSG00000274108',
#  'ENSG00000277356',
#  'ENSG00000263057',
#  'ENSG00000278755',
#  'ENSG00000274786',
#  'ENSG00000275937',
#  'ENSG00000262647',
#  'ENSG00000262068',
#  'ENSG00000276011',
#  'ENSG00000263296',
#  'ENSG00000277552',
#  'ENSG00000262121',
#  'ENSG00000273502',
#  'ENSG00000261958',
#  'ENSG00000263091',
#  'ENSG00000290488',
#  'ENSG00000262191',
#  'ENSG00000281839',
#  'ENSG00000263309',
#  'ENSG00000276218',
#  'ENSG00000276254',
#  'ENSG00000274788',
#  'ENSG00000278758',
#  'ENSG00000275629',
#  'ENSG00000278726',
#  'ENSG00000274947',
#  'ENSG00000276243',
#  'ENSG00000278625',
#  'ENSG00000278025',
#  'ENSG00000279566',
#  'ENSG00000267728',
#  'ENSG00000275974',
#  'ENSG00000263090',
#  'ENSG00000262512',
#  'ENSG00000274746',
#  'ENSG00000262749',
#  'ENSG00000274465',
#  'ENSG00000274574',
#  'ENSG00000273990',
#  'ENSG00000262573',
#  'ENSG00000273757',
#  'ENSG00000262218',
#  'ENSG00000262896',
#  'ENSG00000263263',
#  'ENSG00000262221',
#  'ENSG00000262845',
#  'ENSG00000262542',
#  'ENSG00000279280',
#  'ENSG00000279112',
#  'ENSG00000262594',
#  'ENSG00000280830',
#  'ENSG00000274891',
#  'ENSG00000275416',
#  'ENSG00000276395',
#  'ENSG00000276310',
#  'ENSG00000276465',
#  'ENSG00000262808',
#  'ENSG00000262731',
#  'ENSG00000263229',
#  'ENSG00000277392',
#  'ENSG00000262347',
#  'ENSG00000262520',
#  'ENSG00000263243',
#  'ENSG00000277028',
#  'ENSG00000261862',
#  'ENSG00000262164',
#  'ENSG00000275353',
#  'ENSG00000277442',
#  'ENSG00000278809',
#  'ENSG00000261852',
#  'ENSG00000263101',
#  'ENSG00000262862',
#  'ENSG00000263236',
#  'ENSG00000274429',
#  'ENSG00000263242',
#  'ENSG00000278368',
#  'ENSG00000266286',
#  'ENSG00000282469',
#  'ENSG00000261968',
#  'ENSG00000276333',
#  'ENSG00000282650',
#  'ENSG00000278495',
#  'ENSG00000276882',
#  'ENSG00000282069',
#  'ENSG00000281763',
#  'ENSG00000281250',
#  'ENSG00000275637',
#  'ENSG00000276371',
#  'ENSG00000281151',
#  'ENSG00000277101',
#  'ENSG00000281020',
#  'ENSG00000277603',
#  'ENSG00000276625',
#  'ENSG00000275047',
#  'ENSG00000275511',
#  'ENSG00000282112',
#  'ENSG00000262102',
#  'ENSG00000282176',
#  'ENSG00000275306',
#  'ENSG00000278403',
#  'ENSG00000281157',
#  'ENSG00000278116',
#  'ENSG00000275051',
#  'ENSG00000290333',
#  'ENSG00000275500',
#  'ENSG00000276327',
#  'ENSG00000280635',
#  'ENSG00000277354',
#  'ENSG00000274957',
#  'ENSG00000282103',
#  'ENSG00000282245',
#  'ENSG00000282665',
#  'ENSG00000276086',
#  'ENSG00000262679',
#  'ENSG00000280759',
#  'ENSG00000278481',
#  'ENSG00000278229',
#  'ENSG00000277163',
#  'ENSG00000278086',
#  'ENSG00000273603',
#  'ENSG00000273922',
#  'ENSG00000280986',
#  'ENSG00000275608',
#  'ENSG00000274657',
#  'ENSG00000282649',
#  'ENSG00000282302',
#  'ENSG00000280807',
#  'ENSG00000275037',
#  'ENSG00000282734',
#  'ENSG00000277445',
#  'ENSG00000278788',
#  'ENSG00000277518',
#  'ENSG00000282001',
#  'ENSG00000282152',
#  'ENSG00000278070',
#  'ENSG00000280618',
#  'ENSG00000278508',
#  'ENSG00000276582',
#  'ENSG00000273883',
#  'ENSG00000278373',
#  'ENSG00000278821',
#  'ENSG00000277389',
#  'ENSG00000280585',
#  'ENSG00000278728',
#  'ENSG00000278620',
#  'ENSG00000281919',
#  'ENSG00000278302',
#  'ENSG00000277909',
#  'ENSG00000281261',
#  'ENSG00000277069',
#  'ENSG00000281176',
#  'ENSG00000281690',
#  'ENSG00000278165',
#  'ENSG00000282606',
#  'ENSG00000274296',
#  'ENSG00000277205',
#  'ENSG00000282752',
#  'ENSG00000275326',
#  'ENSG00000281829',
#  'ENSG00000276856',
#  'ENSG00000281618',
#  'ENSG00000280716',
#  'ENSG00000281191',
#  'ENSG00000281830',
#  'ENSG00000281533',
#  'ENSG00000279389',
#  'ENSG00000281758',
#  'ENSG00000280838',
#  'ENSG00000278361',
#  'ENSG00000262860',
#  'ENSG00000276731',
#  'ENSG00000262634',
#  'ENSG00000276177',
#  'ENSG00000274394',
#  'ENSG00000275031',
#  'ENSG00000278759',
#  'ENSG00000282110',
#  'ENSG00000262473',
#  'ENSG00000273666',
#  'ENSG00000275338',
#  'ENSG00000278692',
#  'ENSG00000275522',
#  'ENSG00000280765',
#  'ENSG00000276896',
#  'ENSG00000262911',
#  'ENSG00000281486',
#  'ENSG00000274404',
#  'ENSG00000278489',
#  'ENSG00000278659',
#  'ENSG00000262795',
#  'ENSG00000275754',
#  'ENSG00000281783',
#  'ENSG00000281733',
#  'ENSG00000277175',
#  'ENSG00000275617',
#  'ENSG00000275920',
#  'ENSG00000278429',
#  'ENSG00000277068',
#  'ENSG00000274320',
#  'ENSG00000278210',
#  'ENSG00000281489',
#  'ENSG00000273651',
#  'ENSG00000273508',
#  'ENSG00000280737',
#  'ENSG00000277291',
#  'ENSG00000281801',
#  'ENSG00000277113',
#  'ENSG00000275102',
#  'ENSG00000273793',
#  'ENSG00000274042',
#  'ENSG00000281775',
#  'ENSG00000290526',
#  'ENSG00000261846',
#  'ENSG00000263160',
#  'ENSG00000226463',
#  'ENSG00000282214',
#  'ENSG00000281216',
#  'ENSG00000273831',
#  'ENSG00000280541',
#  'ENSG00000281289',
#  'ENSG00000281019',
#  'ENSG00000263141',
#  'ENSG00000276920',
#  'ENSG00000276455',
#  'ENSG00000262938',
#  'ENSG00000274780',
#  'ENSG00000277365',
#  'ENSG00000276485',
#  'ENSG00000236927',
#  'ENSG00000277278',
#  'ENSG00000272835',
#  'ENSG00000291162',
#  'ENSG00000274112',
#  'ENSG00000277251',
#  'ENSG00000273397',
#  'ENSG00000234495',
#  'ENSG00000275211',
#  'ENSG00000276482',
#  'ENSG00000281184',
#  'ENSG00000272000',
#  'ENSG00000274679',
#  'ENSG00000275333',
#  'ENSG00000281038',
#  'ENSG00000263150',
#  'ENSG00000262315',
#  'ENSG00000261897',
#  'ENSG00000262851',
#  'ENSG00000262755',
#  'ENSG00000262611',
#  'ENSG00000262784',
#  'ENSG00000281580',
#  'ENSG00000263328',
#  'ENSG00000262796',
#  'ENSG00000277848',
#  'ENSG00000278427',
#  'ENSG00000280552',
#  'ENSG00000272532',
#  'ENSG00000260873',
#  'ENSG00000262788',
#  'ENSG00000234411',
#  'ENSG00000272793',
#  'ENSG00000225351',
#  'ENSG00000274513',
#  'ENSG00000275430',
#  'ENSG00000275555',
#  'ENSG00000235788',
#  'ENSG00000280592',
#  'ENSG00000276461',
#  'ENSG00000233054',
#  'ENSG00000280883',
#  'ENSG00000228147',
#  'ENSG00000276613',
#  'ENSG00000274763',
#  'ENSG00000235915',
#  'ENSG00000275658',
#  'ENSG00000276798',
#  'ENSG00000277709',
#  'ENSG00000275544',
#  'ENSG00000276875',
#  'ENSG00000275623',
#  'ENSG00000276163',
#  'ENSG00000275626',
#  'ENSG00000275838',
#  'ENSG00000275873',
#  'ENSG00000276145',
#  'ENSG00000277025',
#  'ENSG00000261893',
#  'ENSG00000276082',
#  'ENSG00000273822',
#  'ENSG00000282810',
#  'ENSG00000276595',
#  'ENSG00000278216',
#  'ENSG00000276016',
#  'ENSG00000276230',
#  'ENSG00000276572',
#  'ENSG00000226271',
#  'ENSG00000231179',
#  'ENSG00000281308',
#  'ENSG00000278114',
#  'ENSG00000273944',
#  'ENSG00000275190',
#  'ENSG00000276452',
#  'ENSG00000274672',
#  'ENSG00000262785',
#  'ENSG00000274511',
#  'ENSG00000276065',
#  'ENSG00000277132',
#  'ENSG00000273943',
#  'ENSG00000278468',
#  'ENSG00000273984',
#  'ENSG00000237703',
#  'ENSG00000274254',
#  'ENSG00000274058',
#  'ENSG00000274185',
#  'ENSG00000277629',
#  'ENSG00000263290',
#  'ENSG00000278426',
#  'ENSG00000236967',
#  'ENSG00000275731',
#  'ENSG00000277071',
#  'ENSG00000278154',
#  'ENSG00000275272',
#  'ENSG00000274873',
#  'ENSG00000231350',
#  'ENSG00000290505',
#  'ENSG00000274382',
#  'ENSG00000235722',
#  'ENSG00000228978',
#  'ENSG00000232289',
#  'ENSG00000275935',
#  'ENSG00000234096',
#  'ENSG00000276363',
#  'ENSG00000262446',
#  'ENSG00000274953',
#  'ENSG00000281407',
#  'ENSG00000274137',
#  'ENSG00000275323',
#  'ENSG00000274050',
#  'ENSG00000278355',
#  'ENSG00000276982',
#  'ENSG00000276825',
#  'ENSG00000277923',
#  'ENSG00000282712',
#  'ENSG00000275724',
#  'ENSG00000263324',
#  'ENSG00000278362',
#  'ENSG00000275551',
#  'ENSG00000276561',
#  'ENSG00000276804',
#  'ENSG00000278501',
#  'ENSG00000281300',
#  'ENSG00000262666',
#  'ENSG00000272765',
#  'ENSG00000262024',
#  'ENSG00000278789',
#  'ENSG00000275086',
#  'ENSG00000274894',
#  'ENSG00000272901',
#  'ENSG00000274146',
#  'ENSG00000277667',
#  'ENSG00000276068',
#  'ENSG00000274005',
#  'ENSG00000281429',
#  'ENSG00000282075',
#  'ENSG00000273642',
#  'ENSG00000275843',
#  'ENSG00000281349',
#  'ENSG00000273833',
#  'ENSG00000277953',
#  'ENSG00000277177',
#  'ENSG00000282334',
#  'ENSG00000275196',
#  'ENSG00000282397',
#  'ENSG00000273884',
#  'ENSG00000282053',
#  'ENSG00000273645',
#  'ENSG00000276536',
#  'ENSG00000226799',
#  'ENSG00000227858',
#  'ENSG00000273896',
#  'ENSG00000242289',
#  'ENSG00000225550',
#  'ENSG00000274174',
#  'ENSG00000282435',
#  'ENSG00000275123',
#  'ENSG00000274726',
#  'ENSG00000273916',
#  'ENSG00000281742',
#  'ENSG00000276051',
#  'ENSG00000278634',
#  'ENSG00000278490',
#  'ENSG00000274504',
#  'ENSG00000282005',
#  'ENSG00000273859',
#  'ENSG00000234305',
#  'ENSG00000274803',
#  'ENSG00000227222',
#  'ENSG00000276342',
#  'ENSG00000276420',
#  'ENSG00000274739',
#  'ENSG00000274126',
#  'ENSG00000273572',
#  'ENSG00000278415',
#  'ENSG00000232804',
#  'ENSG00000277853',
#  'ENSG00000232569',
#  'ENSG00000278021',
#  'ENSG00000278046',
#  'ENSG00000277807',
#  'ENSG00000274109',
#  'ENSG00000275404',
#  'ENSG00000273865',
#  'ENSG00000276370',
#  'ENSG00000263238',
#  'ENSG00000281573',
#  'ENSG00000273936',
#  'ENSG00000278120',
#  'ENSG00000278707',
#  'ENSG00000262505',
#  'ENSG00000274311',
#  'ENSG00000262635',
#  'ENSG00000275349',
#  'ENSG00000275546',
#  'ENSG00000274646',
#  'ENSG00000275581',
#  'ENSG00000276209',
#  'ENSG00000278288',
#  'ENSG00000262599',
#  'ENSG00000278656',
#  'ENSG00000274084',
#  'ENSG00000280840',
#  'ENSG00000261994',
#  'ENSG00000290431',
#  'ENSG00000274473',
#  'ENSG00000275577',
#  'ENSG00000282367',
#  'ENSG00000274131',
#  'ENSG00000275571',
#  'ENSG00000275960',
#  'ENSG00000278555',
#  'ENSG00000277131',
#  'ENSG00000278565',
#  'ENSG00000262771',
#  'ENSG00000279552',
#  'ENSG00000276219',
#  'ENSG00000282185',
#  'ENSG00000281630',
#  'ENSG00000275644',
#  'ENSG00000280501',
#  'ENSG00000275584',
#  'ENSG00000278613',
#  'ENSG00000262327',
#  'ENSG00000274796',
#  'ENSG00000274843',
#  'ENSG00000281317',
#  'ENSG00000278279',
#  'ENSG00000281484',
#  'ENSG00000275633',
#  'ENSG00000263042',
#  'ENSG00000223898',
#  'ENSG00000273494',
#  'ENSG00000226832',
#  'ENSG00000277751',
#  'ENSG00000233095',
#  'ENSG00000276323',
#  'ENSG00000262927',
#  'ENSG00000276220',
#  'ENSG00000262607',
#  'ENSG00000276826',
#  'ENSG00000277722',
#  'ENSG00000278322',
#  'ENSG00000275539',
#  'ENSG00000277615',
#  'ENSG00000276464',
#  'ENSG00000275796',
#  'ENSG00000263137',
#  'ENSG00000274000',
#  'ENSG00000277800',
#  'ENSG00000274362',
#  'ENSG00000262435',
#  'ENSG00000275117',
#  'ENSG00000276429',
#  'ENSG00000278257',
#  'ENSG00000276463',
#  'ENSG00000276022',
#  'ENSG00000276184',
#  'ENSG00000233636',
#  'ENSG00000243441',
#  'ENSG00000234100',
#  'ENSG00000274144',
#  'ENSG00000237258',
#  'ENSG00000237010',
#  'ENSG00000274176',
#  'ENSG00000236522',
#  'ENSG00000225188',
#  'ENSG00000196299',
#  'ENSG00000239741',
#  'ENSG00000262145',
#  'ENSG00000278096',
#  'ENSG00000243612',
#  'ENSG00000231094',
#  'ENSG00000276618',
#  'ENSG00000278284',
#  'ENSG00000274926',
#  'ENSG00000281950',
#  'ENSG00000273529',
#  'ENSG00000228652',
#  'ENSG00000236560',
#  'ENSG00000276146',
#  'ENSG00000275483',
#  'ENSG00000235754',
#  'ENSG00000276774',
#  'ENSG00000275384',
#  'ENSG00000282379',
#  'ENSG00000224319',
#  'ENSG00000276066',
#  'ENSG00000236729',
#  'ENSG00000274626',
#  'ENSG00000262201',
#  'ENSG00000275125',
#  'ENSG00000237108',
#  'ENSG00000230463',
#  'ENSG00000282643',
#  'ENSG00000274161',
#  'ENSG00000276260',
#  'ENSG00000274053',
#  'ENSG00000237050',
#  'ENSG00000223448',
#  'ENSG00000282147',
#  'ENSG00000276887',
#  'ENSG00000282309',
#  'ENSG00000290511',
#  'ENSG00000231319',
#  'ENSG00000224446',
#  'ENSG00000272803',
#  'ENSG00000278682',
#  'ENSG00000282461',
#  'ENSG00000223852',
#  'ENSG00000239836',
#  'ENSG00000262111',
#  'ENSG00000263028',
#  'ENSG00000229470',
#  'ENSG00000274638',
#  'ENSG00000272712',
#  'ENSG00000278363',
#  'ENSG00000273326',
#  'ENSG00000273431',
#  'ENSG00000273086',
#  'ENSG00000273579',
#  'ENSG00000278712',
#  'ENSG00000274941',
#  'ENSG00000261936',
#  'ENSG00000263097',
#  'ENSG00000273457',
#  'ENSG00000278608',
#  'ENSG00000281377',
#  'ENSG00000262525',
#  'ENSG00000277114',
#  'ENSG00000273092',
#  'ENSG00000236315',
#  'ENSG00000280513',
#  'ENSG00000274538',
#  'ENSG00000237051',
#  'ENSG00000273564',
#  'ENSG00000281787',
#  'ENSG00000275837',
#  'ENSG00000274194',
#  'ENSG00000278191',
#  'ENSG00000277079',
#  'ENSG00000276495',
#  'ENSG00000276628',
#  'ENSG00000233813',
#  'ENSG00000276766',
#  'ENSG00000273875',
#  'ENSG00000273506',
#  'ENSG00000235135',
#  'ENSG00000275931',
#  'ENSG00000282181',
#  'ENSG00000275118',
#  'ENSG00000236873',
#  'ENSG00000262986',
#  'ENSG00000272805',
#  'ENSG00000282594',
#  'ENSG00000282013',
#  'ENSG00000275575',
#  'ENSG00000274905',
#  'ENSG00000278378',
#  'ENSG00000234079',
#  'ENSG00000236843',
#  'ENSG00000236250',
#  'ENSG00000273607',
#  'ENSG00000275181',
#  'ENSG00000276341',
#  'ENSG00000276275',
#  'ENSG00000273991',
#  'ENSG00000275365',
#  'ENSG00000274078',
#  'ENSG00000277607',
#  'ENSG00000277359',
#  'ENSG00000282019',
#  'ENSG00000276802',
#  'ENSG00000277263',
#  'ENSG00000278466',
#  'ENSG00000278519',
#  'ENSG00000274437',
#  'ENSG00000275798',
#  'ENSG00000277753',
#  'ENSG00000277179',
#  'ENSG00000276061',
#  'ENSG00000231488',
#  'ENSG00000277090',
#  'ENSG00000278303',
#  'ENSG00000278533',
#  'ENSG00000275744',
#  'ENSG00000281524',
#  'ENSG00000275462',
#  'ENSG00000290343',
#  'ENSG00000281385',
#  'ENSG00000274305',
#  'ENSG00000274889',
#  'ENSG00000277361',
#  'ENSG00000276159',
#  'ENSG00000233314',
#  'ENSG00000278270',
#  'ENSG00000278670',
#  'ENSG00000281988',
#  'ENSG00000230791',
#  'ENSG00000282735',
#  'ENSG00000282107',
#  'ENSG00000282291',
#  'ENSG00000282664',
#  'ENSG00000223687',
#  'ENSG00000274616',
#  'ENSG00000277414',
#  'ENSG00000277730',
#  'ENSG00000276263',
#  'ENSG00000229341',
#  'ENSG00000249032',
#  'ENSG00000235487',
#  'ENSG00000235259',
#  'ENSG00000274651',
#  'ENSG00000262334',
#  'ENSG00000232178',
#  'ENSG00000277273',
#  'ENSG00000234063',
#  'ENSG00000278186',
#  'ENSG00000282130',
#  'ENSG00000275399',
#  'ENSG00000230995',
#  'ENSG00000282444',
#  'ENSG00000275917',
#  'ENSG00000278516',
#  'ENSG00000277178',
#  'ENSG00000277281',
#  'ENSG00000282813',
#  'ENSG00000274566',
#  'ENSG00000277015',
#  'ENSG00000274110',
#  'ENSG00000233439',
#  'ENSG00000274734',
#  'ENSG00000234343',
#  'ENSG00000282515',
#  'ENSG00000275568',
#  'ENSG00000277824',
#  'ENSG00000275723',
#  'ENSG00000282266',
#  'ENSG00000281296',
#  'ENSG00000226858',
#  'ENSG00000277421',
#  'ENSG00000278081',
#  'ENSG00000282076',
#  'ENSG00000241701',
#  'ENSG00000228894',
#  'ENSG00000226704',
#  'ENSG00000231543',
#  'ENSG00000282343',
#  'ENSG00000275499',
#  'ENSG00000275474',
#  'ENSG00000274914',
#  'ENSG00000273562',
#  'ENSG00000276504',
#  'ENSG00000277776',
#  'ENSG00000275013',
#  'ENSG00000226768',
#  'ENSG00000274965',
#  'ENSG00000243958',
#  'ENSG00000225228',
#  'ENSG00000272670',
#  'ENSG00000223654',
#  'ENSG00000290518',
#  'ENSG00000230505',
#  'ENSG00000277733',
#  'ENSG00000230675',
#  'ENSG00000272907',
#  'ENSG00000274669',
#  'ENSG00000234893',
#  'ENSG00000274412',
#  'ENSG00000231325',
#  'ENSG00000275165',
#  'ENSG00000234549',
#  'ENSG00000237724',
#  'ENSG00000276296',
#  'ENSG00000206446',
#  'ENSG00000275979',
#  'ENSG00000228691',
#  'ENSG00000184494',
#  'ENSG00000236251',
#  'ENSG00000282604',
#  'ENSG00000237006',
#  'ENSG00000233490',
#  'ENSG00000238226',
#  'ENSG00000274921',
#  'ENSG00000226437',
#  'ENSG00000279643',
#  'ENSG00000275463',
#  'ENSG00000235668',
#  'ENSG00000206470',
#  'ENSG00000275861',
#  'ENSG00000229467',
#  'ENSG00000234101',
#  'ENSG00000206467',
#  'ENSG00000276421',
#  'ENSG00000236826',
#  'ENSG00000231257',
#  'ENSG00000278723',
#  'ENSG00000227861',
#  'ENSG00000273911',
#  'ENSG00000137394',
#  'ENSG00000227816',
#  'ENSG00000248496',
#  'ENSG00000277106',
#  'ENSG00000274703',
#  'ENSG00000282799',
#  'ENSG00000235966',
#  'ENSG00000281093',
#  'ENSG00000233046',
#  'ENSG00000276458',
#  'ENSG00000275990',
#  'ENSG00000273622',
#  'ENSG00000277924',
#  'ENSG00000206523',
#  'ENSG00000231973',
#  'ENSG00000228738',
#  'ENSG00000276907',
#  'ENSG00000206450',
#  'ENSG00000277398',
#  'ENSG00000276701',
#  'ENSG00000280688',
#  'ENSG00000281861',
#  'ENSG00000227420',
#  'ENSG00000277457',
#  'ENSG00000226139',
#  'ENSG00000274665',
#  'ENSG00000281065',
#  'ENSG00000277996',
#  'ENSG00000231321',
#  'ENSG00000278695',
#  'ENSG00000227596',
#  'ENSG00000259101',
#  'ENSG00000231860',
#  'ENSG00000226898',
#  'ENSG00000231314',
#  'ENSG00000235155',
#  'ENSG00000276734',
#  'ENSG00000278365',
#  'ENSG00000276537',
#  'ENSG00000277401',
#  'ENSG00000229300',
#  'ENSG00000274533',
#  'ENSG00000276739',
#  'ENSG00000275758',
#  'ENSG00000263014',
#  'ENSG00000282750',
#  'ENSG00000233950',
#  'ENSG00000278006',
#  'ENSG00000275819',
#  'ENSG00000226127',
#  'ENSG00000274571',
#  'ENSG00000281213',
#  'ENSG00000280943',
#  'ENSG00000262418',
#  'ENSG00000231116',
#  'ENSG00000277897',
#  'ENSG00000282307',
#  'ENSG00000226651',
#  'ENSG00000274495',
#  'ENSG00000277060',
#  'ENSG00000276336',
#  'ENSG00000281748',
#  'ENSG00000273707',
#  'ENSG00000224544',
#  'ENSG00000237105',
#  'ENSG00000282355',
#  'ENSG00000224994',
#  'ENSG00000275300',
#  'ENSG00000276130',
#  'ENSG00000278545',
#  'ENSG00000229681',
#  'ENSG00000276126',
#  'ENSG00000276446',
#  'ENSG00000277495',
#  'ENSG00000230293',
#  'ENSG00000277926',
#  'ENSG00000275565',
#  'ENSG00000281670',
#  'ENSG00000282620',
#  'ENSG00000274675',
#  'ENSG00000276799',
#  'ENSG00000223767',
#  'ENSG00000233618',
#  'ENSG00000230279',
#  'ENSG00000278119',
#  'ENSG00000278567',
#  'ENSG00000276886',
#  'ENSG00000278729',
#  'ENSG00000274542',
#  'ENSG00000276262',
#  'ENSG00000224979',
#  'ENSG00000275246',
#  'ENSG00000274952',
#  'ENSG00000233795',
#  'ENSG00000276021',
#  'ENSG00000276787',
#  'ENSG00000275885',
#  'ENSG00000262375',
#  'ENSG00000277943',
#  'ENSG00000274454',
#  'ENSG00000278718',
#  'ENSG00000276042',
#  'ENSG00000229125',
#  'ENSG00000278855',
#  'ENSG00000229861',
#  'ENSG00000273525',
#  'ENSG00000206245',
#  'ENSG00000273538',
#  'ENSG00000226634',
#  'ENSG00000277614',
#  'ENSG00000235941',
#  'ENSG00000277086',
#  'ENSG00000240389',
#  'ENSG00000277390',
#  'ENSG00000275746',
#  'ENSG00000276358',
#  'ENSG00000277564',
#  'ENSG00000280555',
#  'ENSG00000280686',
#  'ENSG00000281624',
#  'ENSG00000281553',
#  'ENSG00000277949',
#  'ENSG00000290513',
#  'ENSG00000204692',
#  'ENSG00000278312',
#  'ENSG00000276977',
#  'ENSG00000196231',
#  'ENSG00000233687',
#  'ENSG00000278776',
#  'ENSG00000290542',
#  'ENSG00000278622',
#  'ENSG00000278310',
#  'ENSG00000238289',
#  ...]

# %%
[elem for elem in idmap._sources[0]._lookup['ensg']['entr'].index if elem not in idmap._sources[1]._lookup['ensg']['entr'].index]

# %%
[elem for elem in idmap._sources[0]._lookup['ensg']['entr'].index if elem not in idmap._sources[1]._lookup['ensg']['entr'].index]

# %%
idmap.convert(['ENSG00000159388','ENSG00000211459','ENSG00000159388'],'ensg','ensp', multi_hits='all')
# Out:
# One or more sources do not support the requested input/output ID type mapping: hgnc,mygene
# Mapping will be executed using the following source(s): ensembl
# ['ENSP00000433553|ENSP00000290551', 'N/A', 'ENSP00000433553|ENSP00000290551']

# %%
idmap.convert(['ENSG00000159388','ENSG00000211459','ENSG00000159388'],'ensg','symb', multi_hits='consensus', df=True)
# Out:
# querying 1-3...done.
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
#              input   output  ensembl     hgnc mygene  mismatch  ensembl_hits  \
# 0  ENSG00000159388     BTG2     BTG2     BTG2   BTG2     False             1
# 1  ENSG00000211459  MT-RNR1  MT-RNR1  MT-RNR1   RNR1      True             1
# 2  ENSG00000159388     BTG2     BTG2     BTG2   BTG2     False             1
#
#    hgnc_hits  mygene_hits
# 0          1            1
# 1          1            1
# 2          1            1

# %%
# %debug
# Out:
# > /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py(78)convert()
#      76                 out_df = self.filter_multi_hits(out_df, multi_hits)
#      77                 if self._fill_value == 'passthrough':
# ---> 78                         out_df[out_df == self._fill_value] = pd.Series(id_list).loc[(out_df == self._fill_value).values].values
#      79                 if df:
#      80                         return out_df
#
# ipdb> id_list
# ['1643', '10987', '23369', '1044', '10015', '2185', '10107', '3320', '55014', '9342', 'pippo']
# ipdb> self._fill_value
# 'passthrough'
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user

# %%
idmap.convert('ENSG00000159388','ensg','entr')
# Out:
# querying 1-1...done.
# '7832'

# %%
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()]) # Multiple sources
results =idmap.convert(idmap._sources[0]._lookup['ensg']['symb'][:1000].index,'ensg','symb',df=True)
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-1000...done.
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))

# %%
results[(results.ensembl != results.hgnc) | (results.ensembl != results.mygene)]
# Out:
#                input   output  ensembl     hgnc   mygene  mismatch  \
# 0    ENSG00000210049    MT-TF    MT-TF    MT-TF     TRNF      True
# 1    ENSG00000211459  MT-RNR1  MT-RNR1  MT-RNR1     RNR1      True
# 2    ENSG00000210077    MT-TV    MT-TV    MT-TV     TRNV      True
# 3    ENSG00000210082  MT-RNR2  MT-RNR2  MT-RNR2     RNR2      True
# 4    ENSG00000209082   MT-TL1   MT-TL1   MT-TL1    TRNL1      True
# ..               ...      ...      ...      ...      ...       ...
# 995  ENSG00000237010    HCG14    HCG14      N/A    HCG14     False
# 996  ENSG00000237544  MAS1LP1  MAS1LP1      N/A  MAS1LP1     False
# 997  ENSG00000228706     HCG4     HCG4      N/A     HCG4     False
# 998  ENSG00000274176    CNOT3    CNOT3      N/A    CNOT3     False
# 999  ENSG00000235666  SUMO2P1  SUMO2P1      N/A  SUMO2P1     False
#
#      ensembl_hits  hgnc_hits  mygene_hits
# 0               1        1.0            1
# 1               1        1.0            1
# 2               1        1.0            1
# 3               1        1.0            1
# 4               1        1.0            1
# ..            ...        ...          ...
# 995             1        0.0            1
# 996             1        0.0            1
# 997             1        0.0            1
# 998             1        0.0            1
# 999             1        0.0            1
#
# [994 rows x 9 columns]

# %%
idmap = br.IDMapper([br.MyGeneMapper(),br.EnsemblBiomartMapper(),br.HGNCBiomartMapper()]) # Multiple sources
print(idmap.convert(['ENSG00000210049','ENSG00000211459','ENSG00000210082'],'ensg','symb',df=True, multi_hits='consensus').to_markdown())
print(idmap.convert(['ENSG00000210049','ENSG00000211459','ENSG00000210082'],'ensg','symb',df=False, multi_hits='consensus'))
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-3...done.
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py:371: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   out_df.loc[out_df[src_id] != 'N/A', f'{src_id}_hits'] = out_df[src_id].str.split('|').apply(lambda x: len(x))
# |    | input           | output   | mygene   | ensembl   | hgnc    | mismatch   |   mygene_hits |   ensembl_hits |   hgnc_hits |
# |---:|:----------------|:---------|:---------|:----------|:--------|:-----------|--------------:|---------------:|------------:|
# |  0 | ENSG00000210049 | MT-TF    | TRNF     | MT-TF     | MT-TF   | True       |             1 |              1 |           1 |
# |  1 | ENSG00000211459 | MT-RNR1  | RNR1     | MT-RNR1   | MT-RNR1 | True       |             1 |              1 |           1 |
# |  2 | ENSG00000210082 | MT-RNR2  | RNR2     | MT-RNR2   | MT-RNR2 | True       |             1 |              1 |           1 |
# querying 1-3...done.
# ['MT-TF', 'MT-RNR1', 'MT-RNR2']

# %%
idmap = br.IDMapper([br.EnsemblBiomartMapper(),br.HGNCBiomartMapper(),br.MyGeneMapper()]) # Multiple sources
print(idmap.convert(['ENSG00000159388','ENSG00000211459','ENSG00000159388'],'ensg','ensp', multi_hits='all',df=True).to_markdown())
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# One or more sources do not support the requested input/output ID type mapping: hgnc,mygene
# Mapping will be executed using the following source(s): ensembl
# |    | input           | output                          | ensembl                         | mismatch   |   ensembl_hits |
# |---:|:----------------|:--------------------------------|:--------------------------------|:-----------|---------------:|
# |  0 | ENSG00000159388 | ENSP00000433553|ENSP00000290551 | ENSP00000433553|ENSP00000290551 | False      |              2 |
# |  1 | ENSG00000211459 | N/A                             | N/A                             | False      |              0 |
# |  2 | ENSG00000159388 | ENSP00000433553|ENSP00000290551 | ENSP00000433553|ENSP00000290551 | False      |              2 |

# %%
import biorosetta as br
idmap = br.IDMapper('all')
idmap.convert(['imaginary_gene1','imaginary_gene2'],'ensg','entr') # Returns ['N/A', 'N/A']

idmap2 = br.IDMapper('all', fill_value='passthrough')
idmap2.convert(['imaginary_gene1','imaginary_gene2'],'ensg','entr') # Returns ['imaginary_gene1', 'imaginary_gene2']
# Out:
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-2...done.
# - Loading lookup tables from cache (use function EnsemblBiomartMapper.download_data() to force new download)
# - Loading lookup tables from cache (use function HGNCBiomartMapper.download_data() to force new download)
# querying 1-2...done.
# ['imaginary_gene1', 'imaginary_gene2']

# %%
# %debug
# Out:
# > /Users/reema/anaconda2/envs/biorosetta/lib/python3.10/site-packages/pandas/core/indexes/base.py(3805)get_loc()
#    3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
# -> 3805                 raise KeyError(key) from err
#    3806             except TypeError:
#    3807                 # If we have a listlike key, _check_indexing_error will raise
#
# ipdb> u
# > /Users/reema/anaconda2/envs/biorosetta/lib/python3.10/site-packages/pandas/core/frame.py(3805)__getitem__()
#    3803             if self.columns.nlevels > 1:
#    3804                 return self._getitem_multilevel(key)
# -> 3805             indexer = self.columns.get_loc(key)
#    3806             if is_integer(indexer):
#    3807                 indexer = [indexer]
#
# ipdb> u
# > /Users/reema/Postdoc/Libs/biorosetta/biorosetta/classes.py(253)convert()
#     251                         out_df = pd.Series([self._fill_value] * len(id_list), index=id_list)
#     252                 else:
# --> 253                         out_df = output[id_relabel[id_out]].fillna(self._fill_value)
#     254                         out_df = self.filter_multi_hits(out_df, multi_hits)
#     255                         out_df = out_df[~out_df.index.duplicated()].reindex(id_list) # to remove duplicated input IDs in query
#
# ipdb> output
#         notfound
# query
# fsdfsd      True
# dsfsdf      True
# ipdb> exit
